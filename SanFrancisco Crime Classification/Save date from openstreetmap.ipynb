# %% [markdown]
# ### This is a informative for SF crime dataset

# %%
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from time import time
import seaborn as sns
import pandas as pd
import scipy
import zipfile
% matplotlib inline

# %%
import smopy

# %%
map = smopy.Map((37.74862,-122.52469,37.81986,-122.33663),z=12)

# %%
map

# %%
map.show_ipython()

# %%
result = map.to_numpy()

# %%
result
# Out:
# array([[[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
#         ...,
#         [242, 239, 233],
#         [242, 239, 233],
#         [242, 239, 233]],
#
#        [[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
#         ...,
#         [216, 202, 184],
#         [218, 196, 137],
#         [214, 176, 110]],
#
#        [[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
#         ...,
#         [240, 203, 148],
#         [252, 214, 164],
#         [252, 214, 164]],
#
#        ...,
#        [[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
#         ...,
#         [181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208]],
#
#        [[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
#         ...,
#         [181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208]],
#
#        [[181, 208, 208],
#         [181, 208, 208],
#         [181, 208, 208],
# ...

# %%
plt.imshow(result,cmap=plt.get_cmap('gray'))

# %%
smopy.TILE_SERVER = "http://tile.basemaps.cartocdn.com/light_all/{z}/{x}/{y}@2x.png"
smopy.TILE_SIZE = 512
map = smopy.Map((37.74862,-122.52469,37.81986,-122.33663),z=12)
map.show_ipython()

# %%
result = map.to_numpy()

# %%
type(result)
# Out:
# numpy.ndarray

# %%
picture = map.to_pil()

# %%
picture
# Out:
# <PIL.Image.Image image mode=RGB size=2048x1024 at 0x11CE1CE10>

# %%
plt.imshow(picture,cmap=plt.get_cmap('gray'))

# %%
type(picture)
# Out:
# PIL.Image.Image

# %%
from PIL import Image
picture.save('mapdata.png')
